# %% [markdown]
# Question no.1 :- Describe the differences between text and binary files in a single paragraph.

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ A text file consists of readable characters, which can be opened by any text editor. On the other hand, binary files are made up of non-readable characters(binary values of 1s and 0s) and symbols, which require specific programs to access its contents.

# %% [markdown]
# Question no.2 :- What are some scenarios where using text files will be the better option? When would you like to use binary files instead of text files?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ Text files used to where data needs to to stored in readable and writable format, so when it is required for further reference it can be easily readable or writable and understandable.
#
# ~ Binary files can be used to store any data; for example, a JPEG image is a binary file designed to be read by a computer system.

# %% [markdown]
# Question no.3 :- What are some of the issues with using binary operations to read and write a Python integer directly to disc?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ The read method returns a sequence of bytes as a string by default. To convert from a string  use numpy.fromfile() with dtype as int while reading and writing a file or by using struct module.

# %% [markdown]
# Question no.4 :- Describe a benefit of using the with keyword instead of explicitly opening a file.

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ Using with keyword the file will be closed as soon as you leave the block. This is beneficial because closing a file is something that can easily be forgotten and ties up resources that you no longer need.

# %% [markdown]
# Question no.5 :- Does Python have the trailing newline while reading a line of text? Does Python append a newline when you write a line of text?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ Python readline() method reads only one complete line from the file given. The readline() method also adds a trailing newline character at the end of the string. Append '\n' at the end of the file when using write() to write a line of text to new line as write() function doesn't create new line automatically.

# %% [markdown]
# Question no.6 :- What file operations enable for random-access operation?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~  seek() and tell() enable for random-access operation in files.

# %% [markdown]
# Question no.7 :- When do you think you'll use the struct package the most?

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ The struct in Python is used to perform the conversion of the C struct (which is seen as a Python byte object) into a Python string of bytes and vice versa. The struct in Python is used for file handling in the case of binary-stored data.

# %% [markdown]
# Question no.8 :- When is pickling the best option?

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ It is used to store Python objects. We don't have to construct the same object again and again. We will create an object once and then save it into a disk (pickling), and later on, we load this object from the disk (unpickling) without having to create the object again. Pickling is mostly useful in Machine Learning.

# %% [markdown]
# Question no.9 :- When will it be best to use the shelve package?

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ The Shelve module is used to store data when using a relational database is not recommended. A shelf object is a dictionary-like object, which is defined in this module. Keys in shelf objects are strings and values are Python objects, that can be handled by the Pickle module.

# %% [markdown]
# Question no.10 :- What is a special restriction when using the shelve package, as opposed to using other data dictionaries?

# %% [markdown]
# Answer no.10

# %% [markdown]
# ~ The shelf dictionary has certain restrictions, only string data type can be used as key in this special dictionary object, whereas any picklable Python object can be used as value.
