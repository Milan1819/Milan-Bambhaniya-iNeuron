# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ *,-,/ and + are expressions while 'hello' and -87.8 are values.

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ String is a datatype which is one of many types of values whereas variable is a placeholder used to store all the values of different types.A variable in itself can't be a value.

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ String - It is collection of one or more characters put within single quotes,double quotes or triple quotes.
#
# ~ Integer - It consists of positive and negative whole numbers.
#
# ~ Floating point numbers - It contains real numbers with decimal point values.
#
# ~ Boolean datatype - It defines the truth value of any expressions or characters.It evaluates them as either True or False.

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ An expression is a combination of values ,variables,operators or call to the function.Expressions produce a value or result which can be passed into functions.

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ Expressions produce values whereas statements do not produce values,statement is a instruction to python interpreter to execute something.

# %% [markdown]
# Answer no.6

# %%
bacon = 22
bacon+1

print(bacon)
# Out:
# 22

# %% [markdown]
# ~ After running the above code bacon contains value 22 as we cannot concatenate any integer value to a variable name.

# %% [markdown]
# Answer no.7

# %%
x = 'spam'+'spamspam'
y = 'spam'*3

print(f"The values of above two terms are {x} and {y} respectively")
# Out:
# The values of above two terms are spamspamspam and spamspamspam respectively

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ By default Python does not allow any integer value as starting character of any variable name.So eggs is a valid variable name and 100 is not.

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ int(),float() and str() functions can be used to get respective versions of a value.

# %% [markdown]
# Answer no.10

# %%
text = 'I have eaten'+ 99 +'burritos'
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-74dbdba761a1> in <module>
# ----> 1 text = 'I have eaten'+ 99 +'burritos'
#       2 print(text)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ~ The the above expression causes an error because string and integer concatenation is not possible in python.
#
# ~ To fix it we have to convert 99 to string value as '99' and then concatenate.

# %%
text1 = 'I have eaten '+ '99' +' burritos'
print(text1)
# Out:
# I have eaten 99 burritos
