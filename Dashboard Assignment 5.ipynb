# %% [markdown]
# Question no.1 :- What does an empty dictionary's code look like?

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ {}

# %% [markdown]
# Question no.2 :- What is the value of a dictionary value with the key'foo' and the value 42?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ {'foo':42}

# %% [markdown]
# Question no.3 :- What is the most significant difference between a dictionary and a list?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ The most significant difference between a dictionary and a list is that the items in dictionary are unordered and in list items are ordered.

# %% [markdown]
# Question no.4 :- What happens if we try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam = {'bar':100}

spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-8296b042a128> in <module>
#       1 spam = {'bar':100}
#       2
# ----> 3 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ we get a KeyError type of error.

# %% [markdown]
# Question no.5 :- If a dictionary is stored in spam,what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ There is no difference.It checks whether a value exists as key in the dictionary.

# %% [markdown]
# Question no.6 :- If a dictionary is stored in spam,what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~ 'cat' in spam checks whether 'cat' key is there in dictionary whereas 'cat' in spam.values() checks whether value 'cat' is there for one of keys in dictionary.

# %% [markdown]
# Question no.7 :- What is the shortcut for the following code?

# %%
if color not is spam:
spam['color'] = 'black'

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ spam.setdefault('color':'black')

# %% [markdown]
# Question no.8 :- How do you "pretty print" dictionary values using which modules and function?

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ from pprint import pprint and use function pprint() instead of print().
