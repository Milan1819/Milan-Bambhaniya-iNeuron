# %% [markdown]
# Question no.1 :- What is the name of the feature responsible for generating Regex objects?

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ The re.compile( ) feature is responsible for generating Regex objects.

# %% [markdown]
# Question no.2 :- Why do raw strings often appear in Regex objects?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ Unlike a regular string, a raw string treats the backslashes ( \ ) as literal characters. Raw strings are useful when you deal with strings that have many backslashes.

# %% [markdown]
# Question no.3 :- What is the return value of the search( ) method?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ The search( ) method searches the string for a match, and returns a Match object if there is a match or else returns none.

# %% [markdown]
# Question no.4 :- From a Match item, how do you get the actual strings that match the pattern?

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ The group( ) method is used to get the actual strings that match the pattern.

# %% [markdown]
# Question no.5 :- In the regex which created from the r'(\d\d\d)-(\d\d\d-\d\d\d\d)', what does group zero cover? Group 2? Group 1?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ Group zero covers the entire match, group 1 cover (\d\d\d); first set of parenthesis and group 2 covers (\d\d\d-\d\d\d\d); second set of parenthesis.

# %% [markdown]
# Question no.6 :- In standard syntax, parenthesis and intervals have distinct meanings. How can you tell a regex that you want it to fit real parenthesis and periods?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~ Periods and parentheses can be escaped with a backslash: \., \( and \).

# %% [markdown]
# Question no.7 :- The findall() method returns a string list or list of string tuples.What causes it to return one of the two options?

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ It depends on group of regex. If the regex has no groups, a list of strings is returned and if the regex has groups, a list of tuples of strings is returned.

# %% [markdown]
# Question no.8 :- In the standard expressions, what does the | character mean?

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ The | character signifies matching either, or between two groups.

# %% [markdown]
# Question no.9 :- In regular expressions, what does the character stand for?

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ 0-9, a-z, A-Z, and _ (underscore) are characters in regular expressions.

# %% [markdown]
# Question no.10 :- In regular expressions, what is the difference between + and * characters?

# %% [markdown]
# Answer no.10

# %% [markdown]
# ~ + matches one or more.
#
# ~ * matches zero or more.

# %% [markdown]
# Question no.11 :- What is the difference between {4} and {4,5} in regular expressions?

# %% [markdown]
# Answer no.11

# %% [markdown]
# ~ {4} matches three instances of the preceding group.
#
# ~ {4,5} matches between four and five instances.

# %% [markdown]
# Question no.12 :- What do \d, \w and \s shorthand character classes signify in regular expressions?

# %% [markdown]
# Answer no.12

# %% [markdown]
# ~ \d - will match digit character.
#
# ~ \w - will match word character.
#
# ~ \s - will match whitespace character.

# %% [markdown]
# Question no.13 :- What do \D, \W and \S shorthand character classes signify in regular expressions?

# %% [markdown]
# Answer no.13

# %% [markdown]
# ~ \D - will match non-digit character.
#
# ~ \W - will match non-word character.
#
# ~ \S - will match non-whitespace character.

# %% [markdown]
# Question no.14 :- What is the difference between .* and .*? in regular expressions?

# %% [markdown]
# Answer no.14

# %% [markdown]
# ~ .* performs greedy match.
#
# ~ .*? performs non-greedy match.

# %% [markdown]
# Question no.15 :- What is the syntax for matching both numbers and lowercase letters with a character class?

# %% [markdown]
# Answer no.15

# %% [markdown]
# ~ [0-9a-z] or [a-z0-9]

# %% [markdown]
# Question no.16 :- What is the procedure for making a normal expression in regex case insensitive?

# %% [markdown]
# Answer no.16

# %% [markdown]
# ~ By passing re.I or re.IGNORECASE as second argument to re.compile( ) will make regex case insensitive.

# %% [markdown]
# Question no.17 :- What does the . character normally match? What does it match if re.DOTALL is passed as 2nd argument in re.compile( )?

# %% [markdown]
# Answer no.17

# %% [markdown]
# ~ The . character usually matches any character except the newline character. If re.DOTALL is passed as 2nd argument in re.compile(), then the . character will also match newline characters.

# %% [markdown]
# Question no.18 :- If numReg=re.compile(r'\d+'), what will numRegex.sub('X', '11 drummers, 10 pipers, five rings, 4 hen') return?

# %% [markdown]
# Answer no.18

# %%
import re
numReg = re.compile(r'\d+')
print(numReg.sub('X', '11 drummers, 10 pipers, five rings, 4 hen'))
# Out:
# X drummers, X pipers, five rings, X hen

# %% [markdown]
# Question no.19 :- What does passing re.VERBOSE as the 2nd argument to re.compile( ) allow to do?

# %% [markdown]
# Answer no.19

# %% [markdown]
# ~ The re.VERBOSE lets you to add whitespace and comments to the string passed to re.compile( ).

# %% [markdown]
# Question no.20 :- How would you write a regex that match a number with comma for every three digits? It must match the given following:
#
# '42'
#
# '1,234'
#
# '6,368,745'
#
# but not the following:
#
# '12,34,567' (which has only two digits between the commas)
#
# '1234' (which lacks commas)

# %% [markdown]
# Answer no.20

# %%
my_regex = re.compile(r"((?<!\d)\d{1,3}(?!\d)(,\d{3})*)")
tx = " 42 rcb rcb rcb 1,234 6,368,745 12,34,567 1234 12345678 56789 RCB1718"
cs = my_regex.findall(tx)
print(cs)
# Out:
# [('42', ''), ('1,234', ',234'), ('6,368,745', ',745'), ('12', ''), ('34,567', ',567')]

# %% [markdown]
# Question no.21 :- How would you write a regex that matches the full name of someone whose last name is Watanabe? You can assume that the first name that comes before it will always be one word that begins with a capital letter. The regex must match the following:
#
# 'Haruto Watanabe'
#
# 'Alice Watanabe'
#
# 'RoboCop Watanabe'
#
# but not the following:
#
# 'haruto Watanabe' (where the first name is not capitalized)
#
# 'Mr. Watanabe' (where the preceding word has a nonletter character)
#
# 'Watanabe' (which has no first name)
#
# 'Haruto watanabe' (where Watanabe is not capitalized)

# %% [markdown]
# Answer no.21

# %%
y = re.compile(r'[A-Z][a-z]*\sWatanabe')
print(y.findall('Gowardhan Watanabe'))
# Out:
# ['Gowardhan Watanabe']

# %% [markdown]
# Question no.22 :- How would you write a regex that matches a sentence where the first word is either Alice, Bob, or Carol; the second word is either eats, pets, or throws; the third word is apples, cats, or baseballs; and the sentence ends with a period? This regex should be case-insensitive. It must match the following:
#
# 'Alice eats apples.'
#
# 'Bob pets cats.'
#
# 'Carol throws baseballs.'
#
# 'Alice throws Apples.'
#
# 'BOB EATS CATS.'
#
# but not the following:
#
# 'RoboCop eats apples.'
#
# 'ALICE THROWS FOOTBALLS.'
#
# 'Carol eats 7 cats.'

# %% [markdown]
# Answer no.22

# %%
z = re.compile(r'(Alice|Bob|Carol)\s(eats|pets|throws)\s(apples|cats|baseballs)\.',re.IGNORECASE)
txt = 'Alice throws baseballs.'
v = z.findall(txt)
print(v)
# Out:
# [('Alice', 'throws', 'baseballs')]
