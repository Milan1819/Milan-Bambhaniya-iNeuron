# %% [markdown]
# Question no.1 :- Make a class called Thing with no contents and print it. Then, create an object called example from this class and also print it. Are the printed values the same or different?

# %% [markdown]
# Answer no.1

# %%
class Thing:
    pass

print(Thing)
# Out:
# <class '__main__.Thing'>

# %%
example = Thing() 
print(example)
# Out:
# <__main__.Thing object at 0x7f1a4c247af0>

# %% [markdown]
# ~ The printed values are not same.

# %% [markdown]
# Question no.2 :- Create a new class called Thing2 and add the value 'abc' to the letters class attribute. Letters should be printed.

# %% [markdown]
# Answer no.2

# %%
class Thing2:
    letters = 'abc'

lt = Thing2() 
print(lt.letters)
# Out:
# abc

# %% [markdown]
# Question no.3 :- Make yet another class called, of course, Thing3. This time, assign the value 'xyz' to an instance (object) attribute called letters. Print letters. Do you need to make an object from the class to do this?

# %% [markdown]
# Answer no.3

# %%
class Thing3:
    def __init__(self,letters):
        self.letters = letters

t3 = Thing3('xyz') 
print(t3.letters)
# Out:
# xyz

# %% [markdown]
# Question no.4 :- Create an Element class with the instance attributes name, symbol, and number. Create a class object with the values 'Hydrogen,' 'H,' and 1.

# %% [markdown]
# Answer no.4

# %%
class Element:
    def __init__(self,name,symbol,number):
        self.name = name 
        self.symbol = symbol
        self.number = number

el = Element('Hydrogen','H',1) 
print(el.name)
print(el.symbol) 
print(el.number)
# Out:
# Hydrogen
# H
# 1

# %% [markdown]
# Question no.5 :- Make a dictionary with these keys and values: 'name': 'Hydrogen', 'symbol': 'H', 'number': 1. Then, create an object called hydrogen from class Element using this dictionary.

# %% [markdown]
# Answer no.5

# %%
my_dict = {'name':'Hydrogen','symbol':'H','number':'1'}

hydrogen = Element(**my_dict)

print(hydrogen.name) 
print(hydrogen.symbol) 
print(hydrogen.number)
# Out:
# Hydrogen
# H
# 1

# %% [markdown]
# Question no.6 :- For the Element class, define a method called dump() that prints the values of the object’s attributes (name, symbol, and number). Create the hydrogen object from this new definition and use dump() to print its attributes.

# %% [markdown]
# Answer no.6

# %%
class Element:
    def __init__(self,name,symbol,number):
        self.name = name 
        self.symbol = symbol
        self.number = number

    def dump(self):
        print(f"The name is {self.name}, the symbol is {self.symbol} and the number is {self.number}")

# %%
hydrogen1 = Element('Hydrogen', 'H',1)
hydrogen1.dump()
# Out:
# The name is Hydrogen, the symbol is H and the number is 1

# %% [markdown]
# Question no.7 :- Call print(hydrogen). In the definition of Element, change the name of method dump to __str__, create a new hydrogen object, and call print(hydrogen) again.

# %% [markdown]
# Answer no.7

# %%
print(hydrogen1)
# Out:
# <__main__.Element object at 0x7f1a4c1e3220>

# %%
class Element:
    def __init__(self,name,symbol,number):
        self.name = name 
        self.symbol = symbol
        self.number = number

    def Str(self):
        print(f"The name is {self.name}, the symbol is {self.symbol} and the number is {self.number}")

# %%
hydrogen2 = Element('Hydrogen', 'H',1)
print(hydrogen2.Str()) 
print(hydrogen2)
# Out:
# The name is Hydrogen, the symbol is H and the number is 1
# None
# <__main__.Element object at 0x7f1a4c204370>

# %% [markdown]
# Question no.8 :- Modify Element to make the attributes name, symbol, and number private. Define a getter property for each to return its value.

# %% [markdown]
# Answer no.8

# %%
class Element:
    def __init__(self,name,symbol,number):
        self.__name = name 
        self.__symbol = symbol
        self.__number = number
    
    def name(self):
        return self.__name
    
    def symbol(self):
        return self.__symbol
    
    def number(self):
        return self.__number

# %%
hydrogen3 = Element('Hydrogen','H',1)
print(hydrogen3.name()) 
print(hydrogen3.symbol())
print(hydrogen3.number())
# Out:
# Hydrogen
# H
# 1

# %% [markdown]
# Question no.9 :- Define three classes: Bear, Rabbit, and Octothorpe. For each, define only one method: eats(). This should return 'berries' (Bear), 'clover' (Rabbit), or 'campers' (Octothorpe). Create one object from each and print what it eats.

# %% [markdown]
# Answer no.9

# %%
class Bear:
    def eats(self):
        return 'berries'

class Rabbit:
    def eats(self):
        return 'clover'

class Octothorpe:
    def eats(self): 
        return 'campers'

# %%
B = Bear() 
R = Rabbit()
O = Octothorpe()

print(B.eats()) 
print(R.eats()) 
print(O.eats())
# Out:
# berries
# clover
# campers

# %% [markdown]
# Question no.10 :- Define these classes: Laser, Claw, and SmartPhone. Each has only one method: does(). This returns 'disintegrate' (Laser), 'crush' (Claw), or 'ring' (SmartPhone). Then, define the class Robot that has one instance (object) of each of these. Define a does() method for the Robot that prints what its component objects do.

# %% [markdown]
# Answer no.10

# %%
class Laser:
    def does(self):
        return 'disintegrate'

class Claw:
    def does(self):
        return 'crush'

class Smartphone:
    def does(self):
        return 'ring'

class Robot:
    def __init__(self):
        self.laser = Laser().does() 
        self.claw = Claw().does() 
        self.smartphone = Smartphone().does() 

    def does(self):
        print(f"Robot has laser to: {self.laser}, claws to: {self.claw} and smartphone to: {self.smartphone}")

# %%
R = Robot()
print(R.does())
# Out:
# Robot has laser to: disintegrate, claws to: crush and smartphone to: ring
# None
