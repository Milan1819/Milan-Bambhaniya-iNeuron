# %% [markdown]
# Question no.1 :- What exactly is [ ]?

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ [ ] is an empty list.

# %% [markdown]
# Question no.2 :- In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value?(Assume [2,4,6,8,10] are in spam)

# %% [markdown]
# Answer no.2

# %%
spam = [2,4,6,8,10]
spam[2] = 'hello'
print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# $ - Let's pretend the spam includes the list ['a','b','c','d'] for the next three queries.

# %% [markdown]
# Question no.3 :- What is the value of spam[int(int('3'*2)/11)]?

# %% [markdown]
# Answer no.3

# %%
spam = ['a','b','c','d']
print(spam[int(int('3'*2)/11)])
# Out:
# d

# %% [markdown]
# Question no.4 :- What is the value of spam[-1]?

# %% [markdown]
# Answer no.4

# %%
spam = ['a','b','c','d']
print(spam[-1])
# Out:
# d

# %% [markdown]
# Question no.5 :- What is the value of spam[:2]?

# %% [markdown]
# Answer no.5

# %%
spam = ['a','b','c','d']
print(spam[:2])
# Out:
# ['a', 'b']

# %% [markdown]
# $ Let's pretend bacon has the list [3.14,'cat',11,'cat', True] for next three questions.

# %% [markdown]
# Question no.6 :- What is the value of bacon.index('cat')?

# %% [markdown]
# Answer no.6

# %%
bacon = [3.14,'cat',11,'cat',True]
print(bacon.index('cat')) #gives value of first occurence
# Out:
# 1

# %% [markdown]
# Question no.7 :- How does bacon.append(99) change the look of the list value in bacon?

# %% [markdown]
# Answer no.7

# %%
bacon = [3.14,'cat',11,'cat',True]
bacon.append(99) #adds 99 at the end. 
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# Question no.8 :- How does bacon.remove('cat') change the look of the list in bacon?

# %% [markdown]
# Answer no.8

# %%
bacon = [3.14,'cat',11,'cat',True]
bacon.remove('cat') #removes value of 1st occurrence
print(bacon)
# Out:
# [3.14, 11, 'cat', True]

# %% [markdown]
# Question no.9 :- What are the list concatenation and list replication operators?

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ List concatenation and replication operators are + and * respectively.

# %% [markdown]
# Question no.10 :- What is the difference between list methods append() and insert()?

# %% [markdown]
# Answer no.10

# %% [markdown]
# ~ append() will add values at the end of the list whereas insert() will add values any given indices of the list.

# %% [markdown]
# Question no.11 :- What are the two methods for removing items from a list?

# %% [markdown]
# Answer no.11

# %% [markdown]
# ~ remove() and del statement are methods for removing items from a list.

# %% [markdown]
# Question no.12 :- Describe how list values and string values are identical.

# %% [markdown]
# Answer no.12

# %% [markdown]
# ~ The methods and operations which are applied to strings can also be applied to lists.Both lists and strings have indexes and slices, can be used in for loops, can be concatenated and replicated, can be passed into len(), can be used with in and not in operators.

# %% [markdown]
# Question no.13 :- What's the difference between tuples and lists?

# %% [markdown]
# Answer no.13

# %% [markdown]
# ~ Lists are mutable while Tuples are immutable.
#
# ~ Lists use [ ] square brackets whereas Tuples use ( ) parenthesis.

# %% [markdown]
# Question no.14 :- How do you type a tuple value that only contains the integer 42?

# %% [markdown]
# Answer no.14

# %% [markdown]
# ~ (42,) - A comma after value is compulsory if only single value is there in tuple.

# %% [markdown]
# Question no.15 :- How do you get a list value's tuple form? How do you get tuple value's list form?

# %% [markdown]
# Answer no.15

# %% [markdown]
# ~ tuple( ) and list( ) functions can be used respectively.

# %% [markdown]
# Question no.16 :- Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# Answer no.16

# %% [markdown]
# ~ They contain references to list values.

# %% [markdown]
# Question no.17 :- How do you distinguish between copy.copy( ) and copy.deepcopy( )?

# %% [markdown]
# Answer no.17

# %% [markdown]
# ~ copy.copy( ) will create shallow copy and copy.deepcopy( ) will create deep copy. Shallow copy creates new object inserts references into the objects found in the original whereas Deep copy inserts copies of the same.
