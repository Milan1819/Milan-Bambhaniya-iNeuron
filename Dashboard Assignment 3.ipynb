# %% [markdown]
# Question no.1 :- Why are functions advantageous to have in your programs?

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ Improves readability of code.
#
# ~ Reduces chances of errors.
#
# ~ Easy for modifications.
#
# ~ Avoid repetition of codes and thus improves usability of codes.
#
# ~ Information hiding.

# %% [markdown]
# Question no.2 :- When does the code in a function run:when it's specified or when it's called?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ The code in a function runs when it's called.

# %% [markdown]
# Question no.3 :- What statement creates a function?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ def function name(arguments): This statement creates a function.

# %% [markdown]
# Question no.4 :- What is the difference between a function and a function call?

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ A function is defined to get a desired result and a function call is to use this function to achieve it.

# %% [markdown]
# Question no.5 :- How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ There are 4 local scopes and 1 global scope in python.

# %% [markdown]
# Question no.6 :- What happens to a variable in a local scope when the function call returns?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~ When the function call returns, the variables in local scope are destroyed.

# %% [markdown]
# Question no.7 :- What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ A return value is a value that function returns to the calling function when it completes its task. Yes,it is possible to have a return value in an expression.

# %% [markdown]
# Question no.8 :- If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ None will be the return value.

# %% [markdown]
# Question no.9 :- How do you make a function variable refer to the global variable?

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ Use "global" keyword before variable name defined inside the function.
#
# ~ Example :-

# %%
def Ipl():
    global z
    z = "RCB is Fabulous team"
    return z

# %%
Ipl()
# Out:
# 'RCB is Fabulous team'

# %% [markdown]
# Question no.10 :- What is the datatype of None?

# %% [markdown]
# Answer no.10

# %% [markdown]
# ~ The datatype of None is Nonetype.

# %% [markdown]
# Question no.11 :- What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# Answer no.11

# %% [markdown]
# ~ It imports the module named  areallyourpetsnamederic.

# %% [markdown]
# Question no.12 :- If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# Answer no.12

# %% [markdown]
# ~ spam.bacon()

# %% [markdown]
# Question no.13 :- What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# Answer no.13

# %% [markdown]
# ~ By using Exception handling we can save programme from crashing.

# %% [markdown]
# Question no.14 :- What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# Answer no.14

# %% [markdown]
# ~ The try clause is used to check any code for errors and except clause is used for exception handling. The code in try block executes successfully if it has no error and if it has some error it will go into the except block.
