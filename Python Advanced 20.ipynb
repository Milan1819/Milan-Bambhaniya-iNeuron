# %% [markdown]
# Question no.1 :- Compare and contrast the float and Decimal classes' benefits and drawbacks.

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ Both the float and decimal types store numerical values in Python.
#
# ~ Use floats when convenience and speed matter. A float gives you an approximation of the number you declare.
#
# ~ Use decimals when precision matters. Decimals can suffer from their own precision issues, but generally, decimals are more precise than floats. The performance difference between float and decimal, with Python 3, is not outlandish, and in my experience, the precision benefits of a decimal outweigh the performance benefits of a float.~

# %% [markdown]
# Question no.2 :- Decimal('1.200') and Decimal('1.2') are two objects to consider. In what sense are these the same object? Are these just two ways of representing the exact same value, or do they correspond to different internal states?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ Both values are same but internal representation at storage Is different. Precision differs, Decimal('1.200') gives internally 1.200 and Decimal('1.2') gives 1.2.

# %% [markdown]
# Question no.3 :- What happens if the equality of Decimal('1.200') and Decimal('1.2') is checked?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ Both values are checked to be equal , they only differ in precision.

# %% [markdown]
# Question no.4 :- Why is it preferable to start a Decimal object with a string rather than a floating-point value?

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ Floating-point value is converted to Decimal format. Decimal can store float value with absolute precision. But when float value is given as Decimal object,it first has to be converted from floating point value which might already have rounding error. So, it is preferable to start a Decimal object with a string.

# %% [markdown]
# Question no.5 :- In an arithmetic phrase, how simple is it to combine Decimal objects with integers?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ We can do it with use of Decimal().

# %% [markdown]
# Question no.6 :- Can Decimal objects and floating-point values be combined easily?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~ Arithmetic operations like Adding,subtracting or multiplying a Decimal object by a floating-point value generates an error. To do these operations, the floating point has to be converted to a Decimal.

# %% [markdown]
# Question no.7 :- Using the Fraction class but not the Decimal class, give an example of a quantity that can be expressed with absolute precision.

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ Value of 0.5 will be represented as ½.

# %% [markdown]
# Question no.8 :- Describe a quantity that can be accurately expressed by the Decimal or Fraction classes but not by a floating-point value.

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ Any number that has infinite number of digits such as 1/3, the square root of 2 and PI cannot be represented completely by floating-point values. Moreover, even a number of finite number of digits cannot be represented precisely because of the way of encoding real numbers.

# %% [markdown]
# Question no.9 :- Consider the following two fraction objects: Fraction(1, 2) and Fraction(1, 2). (5, 10). Is the internal state of these two objects the same? Why do you think that is?

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ Both will be reduced to 1/2

# %% [markdown]
# Question no.10 :- How do the Fraction class and the integer type (int) relate to each other? Containment or inheritance?

# %% [markdown]
# Answer no.10

# %% [markdown]
# ~ Fraction class and integer type(int) are related in form of a container. It contains two integers, one the numerator and the other the denominator.
