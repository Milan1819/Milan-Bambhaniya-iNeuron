# %% [markdown]
# Question no.1 :-
#
#
#
# Define a class with a generator which can iterate the numbers, which are divisible by 7, between a given range 0 and n.

# %% [markdown]
# Answer no.1

# %%
class generator:
    def division(self,n):
        nums = []
        for i in range(0,n):
           if i%5 == 0 and i%7 == 0:
               nums.append(i)
        return nums

g = generator() 
g.division(200)
# Out:
# [0, 35, 70, 105, 140, 175]

# %% [markdown]
# Question no.2 :-
#
# Write a program to compute the frequency of the words from the input. The output should output after sorting the key alphanumerically.
#
#
#
#
# Suppose the following input is supplied to the program:
#
#
#
#
# New to Python or choosing between Python 2 and Python 3? Read Python 2 or Python 3.
#
#
#
#
# Then, the output should be:
#
#
#
#
# 2:2
#
#
#
#
# 3.:1
#
#
#
#
# 3?:1
#
#
#
#
# New:1
#
#
#
#
# Python:5
#
#
#
#
# Read:1
#
#
#
#
# and:1
#
#
#
#
# between:1
#
#
#
#
# choosing:1
#
#
#
#
# or:2
#
#
#
# to:1

# %% [markdown]
# Answer no.2

# %%
def Frequency(string):
    S = string.split()   
    T = list(set(S)) 
    T.sort() 
    
    for i in T:
        print(i,':',S.count(i))

string = input("Write a sentence: ") 
Frequency(string)
# Out:
# Write a sentence: Nory was a Catholic in 1997 because her mother was a Catholic in 1997 and Nory's mother was a Catholic because her father was a Catholic
# 1997 : 2
# Catholic : 4
# Nory : 1
# Nory's : 1
# a : 4
# and : 1
# because : 2
# father : 1
# her : 2
# in : 2
# mother : 2
# was : 4

# %% [markdown]
# Question no.3 :-
#
# Define a class Person and its two child classes: Male and Female. All classes have a method "getGender" which can print "Male" for Male class and "Female" for Female class.

# %% [markdown]
# Answer no.3

# %%
class Person():
    def getGender(self):
        return "Person"
    
    class Male(Person):
        def getGender(self):
            return "Male" 
    
    class Female(Person):
        def getGender(self):
            return "Female"

P = Person() 
M = P.Male()
F = P.Female()
print(P.getGender()) 
print(M.getGender()) 
print(F.getGender())
# Out:
# Person
# Male
# Female

# %% [markdown]
# Question no.4 :-
#
# Please write a program to generate all sentences where subject is in ["I", "You"] and verb is in ["Play", "Love"] and the object is in ["Hockey","Football"].

# %% [markdown]
# Answer no.4

# %%
import itertools
subject = ["I", "You"]
verb = ["Play", "Love"]
objects = ["Hockey","Football"]

sentence = [subject, verb, objects]
sen = list(itertools.product(*sentence))
for i in sen: 
    print(i)
# Out:
# ('I', 'Play', 'Hockey')
# ('I', 'Play', 'Football')
# ('I', 'Love', 'Hockey')
# ('I', 'Love', 'Football')
# ('You', 'Play', 'Hockey')
# ('You', 'Play', 'Football')
# ('You', 'Love', 'Hockey')
# ('You', 'Love', 'Football')

# %% [markdown]
# Question no.5 :-
#
# Please write a program to compress and decompress the string "hello world!hello world!hello world!hello world!".

# %% [markdown]
# Answer no.5

# %%
my_string = 'hello world!hello world!hello world!hello world!'

c = bytes(my_string,'utf-8')

d = zlib.compress(c)

print(x)
print(zlib.decompress(d))
# Out:
# b'x\x9c\xcbH\xcd\xc9\xc9W(\xcf/\xcaIQ\xcc \x82\r\x00\xbd[\x11\xf5'
# b'hello world!hello world!hello world!hello world!'

# %% [markdown]
# Question no.6 :-
#
# Please write a binary search function which searches an item in a sorted list. The function should return the index of element to be searched in the list.

# %% [markdown]
# Answer no.6

# %%
import math

def bin_search(list, element):
    bottom = 0
    top = len(list)-1
    index = -1

    while top >= bottom and index == -1:
        mid = int(math.floor((top+bottom)/2.0))
        if list[mid] == element:
            index = mid
        elif list[mid] > element:
            top = mid-1
        else:
            bottom = mid+1

    return index

list = [35,77,88,93,112,221,117,184]
print(bin_search(list,112))
# Out:
# 4
