# %% [markdown]
# Question no.1 :- What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all ?

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ A probability distribution describes how a random variable is distributed. It tells us which values a random variable is most likely to take on and which values are less likely. Based on the previous data and the occurences of the random event, we can predict the outcome in terms of probabilities.

# %% [markdown]
# Question no.2 :- Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ True Random Numbers are true physical values while pseudo-random numbers are generated internally by a program . Latter is considered good enough as they have sort of uniform distribution.

# %% [markdown]
# Question no.3 :- What are the two main factors that influence the behaviour of a "normal" probability distribution ?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ Normal Probability Distribution are influenced by two factors mean and the variance.

# %% [markdown]
# Question no.4 :- Provide a real-life example of a normal distribution ?

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ Real-life examples of a normal distribution are heights or blood pressure measurements.

# %% [markdown]
# Question no.5 :- In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows ?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ Variance will decrease with number of trials

# %% [markdown]
# Question no.6 :- What kind of object can be shuffled by using random.shuffle ?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~ lists (list), strings (str) and tuples (tuple) objects can be shuffled by using random.shuffle.

# %% [markdown]
# Question no.7 :- Describe the math package's general categories of functions ?

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ The Math package's general categories of functions are:
#
# • Trigonometric functions
#
# • Quadratic functions
#
# • Exponential functions
#
# • Hyperbolic functions
#
# • Periodic functions
#
# • Arithmetic functions
#
# • Logarithmic functions
#
# • Conversions to Integer

# %% [markdown]
# Question no.8 :- What is the relationship between exponentiation and logarithms ?

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ Exponentiation and logarithms are inverse of each other.

# %% [markdown]
# Question no.9 :- What are the three logarithmic functions that Python supports ?

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ The Three Logarithmic Functions that Python supports are:
#
# ~ log2(x) - logarithmic value of x to base 2
#
# ~ log10(x) - logarithmic value of x to base 10
#
# ~ log1p(a) - This function is used to compute logarithm(1+a) .
