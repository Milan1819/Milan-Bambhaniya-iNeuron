# %% [markdown]
# Question no.1 :- What is the purpose of Python's OOP?

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ Object-oriented programming provides a means of structuring programs so that properties and behaviors are bundled into individual objects. It increases the reusability of codes and also makes coding less error prone.

# %% [markdown]
# Question no.2 :- Where does an inheritance search look for an attribute?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ An inheritance search looks for an attribute first in the instance object, then in the class from which the instance was created and then in all higher superclasses, progressing from left to right by default.

# %% [markdown]
# Question no.3 :-How do you distinguish between a class object and an instance object?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ In OOP, variables at the class level are referred to as class objects, whereas variables at the object level are called instance objects.

# %% [markdown]
# Question no.4 :- What makes the first argument in a class’s method function special?

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ The first argument in class's method more often used as (self) is special because it acts as pointer or creates references for all the methods and attributes defined in the class to connect with the class.

# %% [markdown]
# Question no.5 :- What is the purpose of the __init__ method?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ The __init__ method is constructor method in OOP, it's purpose is to allow the class to initialize the attributes of the class.

# %% [markdown]
# Question no.6 :- What is the process for creating a class instance?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~ To create class instance, we call the class using class name and pass in whatever arguments we require in its __init__ method.

# %% [markdown]
# Question no.7 :- What is the process for creating a class?

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ To create a class use the keyword class followed by classname and put a colon after classname. Then create constructors, methods, attributes, subclasses whatever we want in it.

# %% [markdown]
# Question no.8 :- How would you define the superclasses of a class?

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ The class from which subclass or subclasses are derived is called superclass. It is also known as base class.
