# %% [markdown]
# Question no.1 :- Define the relationship between a class and its instances. Is it a one-to-one or a one-to-many partnership, for example?

# %% [markdown]
# Answer no.1

# %% [markdown]
# ~ Relationship between a class and its instances is a one to many partnership.

# %% [markdown]
# Question no.2 :- What kind of data is held only in an instance?

# %% [markdown]
# Answer no.2

# %% [markdown]
# ~ Instance objects contains the Instance variables which are specific to that specific Instance object.

# %% [markdown]
# Question no.3 :- What kind of knowledge is stored in a class?

# %% [markdown]
# Answer no.3

# %% [markdown]
# ~ Class creates a user-defined data structure, which holds its own data members and member functions, which can be accessed and used by creating an instance of that class. A class is like a blueprint for an object.

# %% [markdown]
# Question no.4 :- What exactly is a method, and how is it different from a regular function?

# %% [markdown]
# Answer no.4

# %% [markdown]
# ~ The methods with a class can be used to access the instance variables of its instance. So,the object's state can be modified by its method. Function can't access the attributes of an instance of a class or can't modify the state of the object.

# %% [markdown]
# Question no.5 :- Is inheritance supported in Python, and if so, what is the syntax?

# %% [markdown]
# Answer no.5

# %% [markdown]
# ~ Yes,Python supports inheritance. The Types of Inheritance Supported by Python are:
#
# 1.Simple Inheritance
#
# 2.Multiple Inheritance
#
# 3.Multilevel Inheritance
#
# 4.Hybrid Inheritance
#
# 5.Hierarchical Inheritance

# %%
class Animal:
    def __init__(self, breed, colour):
        self.breed = breed
        self.colour = colour
class Dog(Animal):
    pass

# %% [markdown]
# Question no.6 :- How much encapsulation (making instance or class variables private) does Python support?

# %% [markdown]
# Answer no.6

# %% [markdown]
# ~ Encapsulation describes the idea of wrapping data and the methods that work on data within one unit. This puts restrictions on accessing variables and methods directly and can prevent the accidental modification of data. To prevent accidental change, an objects variable can only be changed by an objects method.

# %% [markdown]
# Question no.7 :- How do you distinguish between a class variable and an instance variable?

# %% [markdown]
# Answer no.7

# %% [markdown]
# ~ The Class Attribute is available to all the instance objects of that class. whereas Instance Attributes are accessible only to the object or Instance of that class.

# %% [markdown]
# Question no.8 :- When, if ever, can self be included in a class's method definitions?

# %% [markdown]
# Answer no.8

# %% [markdown]
# ~ Yes, self can included in class method definations to access the instance variables inside class methods.

# %% [markdown]
# Question no.9 :- What is the difference between the _ add _ and the _ radd _ methods?

# %% [markdown]
# Answer no.9

# %% [markdown]
# ~ Entering __radd__ Python will first try __add__(), and if that returns Not Implemented Python will check if the right-hand operand implements __radd__, and if it does, it will call __radd__() rather than raising a TypeError

# %% [markdown]
# Question no.10 :- When is it necessary to use a reflection method? When do you not need it, even though you support the operation in question?

# %% [markdown]
# Answer no.10

# %% [markdown]
# ~ Reflection method we often encounter the requirement that a method in the executing object, or a variable in the calling object, or a field of the object should be assigned, while the method name or field name can not be determined when encoding the code, and need to be input in the form of passing strings through parameters.

# %% [markdown]
# Question no.11 :- What is the _ iadd _ method called?

# %% [markdown]
# Answer no.11

# %% [markdown]
# ~ __iadd__ method is called when we use implementation like a+=b which is a.__iadd__(b)

# %% [markdown]
# Question no.12 :- Is the _ init _ method inherited by subclasses? What do you do if you need to customize its behavior within a subclass?

# %% [markdown]
# Answer no.12

# %% [markdown]
# ~ Yes, __init__ method will be inherited by subclasses. If we want to customize its behaviour within a subclass we can use super() method.
